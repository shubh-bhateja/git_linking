# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("wine_data.csv" , header = None  , usecols=[0,1,2])
df.columns= ["Class Label" , "Alcohol" , "Malic Acid"]

# %%
df
# Out:
#      Class Label  Alcohol  Malic Acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.distplot(df["Alcohol"]  , hist=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17184\3647734133.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Alcohol"]  , hist=False)
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df["Malic Acid"], df["Alcohol"] , hue=df[]
# Out:
# <Axes: xlabel='Malic Acid', ylabel='Density'>

# %%
color_dict = {1: "red", 2: "green", 3: "blue"}
sns.scatterplot(x=df["Alcohol"], y=df["Malic Acid"], hue=df["Class Label"], palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(df.drop("Class Label" , axis=1) , df["Class Label"] , test_size=0.3 )

# %%
x_train.shape , x_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_test_scaled = pd.DataFrame(x_test_scaled , columns=x_test.columns)
x_train_scaled = pd.DataFrame(x_train_scaled , columns=x_train.columns)

# %%
x_train.describe()
# Out:
#           Alcohol  Malic Acid
# count  124.000000  124.000000
# mean    12.964435    2.312581
# std      0.838588    1.107534
# min     11.030000    0.740000
# 25%     12.320000    1.597500
# 50%     12.945000    1.845000
# 75%     13.645000    3.030000
# max     14.830000    5.800000

# %%
x_train_scaled.describe()
# Out:
#           Alcohol  Malic Acid
# count  124.000000  124.000000
# mean     0.509062    0.310787
# std      0.220681    0.218880
# min      0.000000    0.000000
# 25%      0.339474    0.169466
# 50%      0.503947    0.218379
# 75%      0.688158    0.452569
# max      1.000000    1.000000

# %%
sns.scatterplot(x=x_train["Alcohol"] , y=x_train["Malic Acid"] , data=df , hue=y_train)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>

# %%
sns.scatterplot(x=x_train_scaled["Alcohol"] , y=x_train_scaled["Malic Acid"] , data=df , hue=y_train)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>
