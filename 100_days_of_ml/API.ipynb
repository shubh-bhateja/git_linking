# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=40de1240f1bddcc126ea05d234ec4a63&language=en-US&page=1")

# %%
# Data of ONLY 1 PAGE

# %%
temp_df=pd.DataFrame(response.json()["results"])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      155                                The Dark Knight
# 8      497                                 The Green Mile
# 9   496243                                       Parasite
# 10     680                                   Pulp Fiction
# 11  372058                                     Your Name.
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
# EMPTY DATAFRAME

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_list = []
for i in range(1, 429):
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=40de1240f1bddcc126ea05d234ec4a63&language=en-US&page={}".format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
    df_list.append(temp_df)

df = pd.concat(df_list, ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555   14536               New in Town
# 8556   10379            Drop Dead Fred
# 8557  437626                 Stockholm
# 8558  411873          The Little Hours
# 8559  192134             Dom Hemingway
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.to_csv('movies.csv')
