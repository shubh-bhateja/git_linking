# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("weight-height.csv")

# %%
df.sample(10)
# Out:
#       Gender     Height      Weight
# 2455    Male  69.055747  204.258751
# 1993    Male  65.513623  173.178827
# 8111  Female  62.444089  134.451300
# 6278  Female  64.743643  141.980647
# 8937  Female  62.060245  123.803906
# 6359  Female  58.190089  107.057141
# 6084  Female  59.169604  112.043944
# 586     Male  71.171431  195.382311
# 6032  Female  63.442212  134.801974
# 9520  Female  63.763403  136.230864

# %%
df.shape
# Out:
# (10000, 3)

# %%
sns.boxplot(x=df["Height"])
# Out:
# <Axes: xlabel='Height'>

# %%
sns.distplot(df["Height"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19836\1870637031.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Height"])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
#normally distributed

# %%
# TRIMMING /REMOVING

# %%
upper_limit= df["Height"].quantile(0.99)
upper_limit
# Out:
# np.float64(74.7857900583366)

# %%
lower_limit= df["Height"].quantile(0.01)
lower_limit
# Out:
# np.float64(58.13441158671655)

# %%
non_outliers_df= df[(df["Height"] < upper_limit) & (df["Height"] > lower_limits)]

# %%
non_outliers_df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9800 rows x 3 columns]

# %%
df.columns.value_counts().sum()
# Out:
# np.int64(3)

# %%
a=df.index.value_counts().sum()

# %%
non_outliers_df.columns.value_counts().sum()
# Out:
# np.int64(3)

# %%
b=non_outliers_df.index.value_counts().sum()

# %%
total_outliers=a-b

# %%
total_outliers
# Out:
# np.int64(200)

# %%
## TREATMENT

# %%
non_outliers_df['Height'].describe()
# Out:
# count    9800.000000
# mean       66.364366
# std         3.645075
# min        58.134496
# 25%        63.577162
# 50%        66.318070
# 75%        69.119896
# max        74.785714
# Name: Height, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.boxplot(x=non_outliers_df["Height"])
# Out:
# <Axes: xlabel='Height'>

# %%
sns.distplot(x=non_outliers_df["Height"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19836\925051830.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=non_outliers_df["Height"])
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize= (12,6))

plt.subplot(1,2,1)
sns.distplot(x=df["Height"])
plt.subplot(1,2,2)
sns.distplot(x=non_outliers_df["Height"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19836\409907322.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["Height"])
# C:\Users\User\AppData\Local\Temp\ipykernel_19836\409907322.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# CAPPING  / Winsorization

# %%
# np.where(condition,true,false)

# %%
df["Height"] = np.where(df["Height"] >= upper_limit , upper_limit,
                       np.where(df["Height"] <= lower_limit , lower_limit , df["Height"]))
