# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_regression

# %%
x, y = make_regression(n_samples=4,n_features=1,n_informative=1,random_state=3 , noise = 80)

# %%
plt.scatter(x,y)
plt.show()

# %%
# OLS 
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
m = lr.coef_

# %%
lr.intercept_
# Out:
# np.float64(18.678032773126453)

# %%
plt.scatter(x,y)   
plt.plot(x,lr.predict(x),color='red')
plt.legend()  
plt.title('This is the best fit line')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17108\3951463121.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# applying gd method and finding the best values of the parameters 
y_hat = (m*x) + lr.intercept_

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='OLS')
plt.plot(x,y_hat,color='#00a65a',label='b = 100')
plt.legend()
plt.show()

# %%
# m = 78.35

b = 100

# loss_slope = -2 * np.sum(y - m*X.ravel() - b)
# loss_slope

# %%
loss_slope = -2 * np.sum(y - m*x.ravel() - b)
loss_slope
# Out:
# np.float64(650.5757378149884)

# %%
# Lets take learning rate = 0.1
learning_rate = 0.1

step_size = loss_slope*learning_rate
step_size
# Out:
# np.float64(65.05757378149885)

# %%
b = b - step_size
b
# Out:
# np.float64(34.942426218501154)

# %%
y_pred1 = ((78.35 * x) + b).reshape(4)

plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='OLS')
plt.plot(x,y_pred1,color='#00a65a',label='b = {}'.format(b))
plt.plot(x,y_hat,color='#A3E4D7',label='b = 100')
plt.legend()
plt.show()

# %%
# Iteration 2
loss_slope = -2 * np.sum(y - m*x.ravel() - b)
loss_slope
# Out:
# np.float64(130.1151475629977)

# %%
step_size = loss_slope*learning_rate

# %%
b= b - step_size
b
# Out:
# np.float64(21.930911462201387)

# %%
y_pred2 = ((78.35 * x) + b).reshape(4)

plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='OLS')
plt.plot(x,y_pred2,color='#00a65a',label='b = {}'.format(b))
plt.plot(x,y_pred1,color='#00a65a',label='b = {}'.format(b))
plt.plot(x,y_hat,color='#A3E4D7',label='b = 100')
plt.legend()
plt.show()

# %%
# Iteration 3
loss_slope = -2 * np.sum(y - m*x.ravel() - b)
loss_slope
# Out:
# np.float64(26.02302951259948)

# %%
step_size = loss_slope*learning_rate

# %%
b=b-step_size

# %%
b
# Out:
# np.float64(19.32860851094144)

# %%
y_pred3 = ((78.35 * x) + b)

plt.figure(figsize=(15,15))

plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='OLS')
plt.plot(x,y_pred3,color='red',label='b = {}'.format(b))
plt.plot(x,y_pred2,color='#00a65a',label='b = {}'.format(b))
plt.plot(x,y_pred1,color='#00a65a',label='b = {}'.format(b))
plt.plot(x,y_hat,color='#A3E4D7',label='b = 100')
plt.legend()
plt.show()
plt.figure(figsize=(15,15))

# %%
b = 100
m = 78.35
lr = 0.01

epochs = 1000
plt.figure(figsize=(15,15))
for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*x.ravel() - b)
  b = b - (lr * loss_slope)

  y_pred = m * x + b

  plt.plot(x,y_pred)

plt.scatter(x,y)
