# %%
import requests

url = "https://imdb232.p.rapidapi.com/api/news/get-by-category"

querystring = {"limit":"25","category":"CELEBRITY"}

headers = {
	"x-rapidapi-key": "1e23c08981mshef84cd9f8aac95cp154ef9jsn5ca4a6b1b5d9",
	"x-rapidapi-host": "imdb232.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

# %%
df = pd.read_csv("vehicle_owner_mock_data_120.csv")

# %%
df.sample(15)
# Out:
#     vehicle_no       owner_name  contact_number                      email  \
# 44    MH439204     Vivaan Dixit      5638509146        divitkant@gmail.com
# 39    GJ955665   Yasmin Trivedi      6453216811          qmangal@yahoo.com
# 2     KA792548        Aarna Din      1363398036       rohandugar@yahoo.com
# 42    UP235124     Ishita Garde      2561369922         madhup97@gmail.com
# 102   RJ947230     Indrans Bala    918144165371        sahil29@hotmail.com
# 95    HR553327      Advika Kala    916140460633          ksharma@gmail.com
# 27    RJ738955       Prisha Raj      3800559038     dhanukganesh@gmail.com
# 62    PB465287   Chirag Agarwal      9362292293  uthkarshkapur@korpal.info
# 10    HR832474   Alisha Thakkar      6440079102     rashajhaveri@yahoo.com
# 117   DL099843     Ayesha Boase      3036128306      seherlall@hotmail.com
# 76    KA295824      Gatik Shere      2968298379       chanavedika@kara.com
# ...
